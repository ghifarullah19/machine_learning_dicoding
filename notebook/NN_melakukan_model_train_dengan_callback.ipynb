# %%
import tensorflow as tf
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv('sample_data/Iris.csv')
df = df.drop(columns='Id')

# %%
category = pd.get_dummies(df.Species, dtype=float)

# %%
new_df = pd.concat([df, category], axis=1)
new_df = new_df.drop(columns='Species')

# %%
dataset = new_df.values

# %%
X = dataset[:,0:4]
y = dataset[:,4:7]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
model = Sequential([
                    Dense(64, activation='relu', input_shape=(4,)),
                    Dense(64, activation='relu'),
                    Dense(3, activation='softmax'),])

# %%
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if logs.get('accuracy') > 0.9:
      print('\nAkurasi telah mencapai > 90%!')
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.fit(X_train, Y_train, epochs=50, callbacks=[callbacks])
# Out:
# Epoch 1/50
# 4/4 [==============================] - 2s 11ms/step - loss: 1.1127 - accuracy: 0.3238
# Epoch 2/50
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0735 - accuracy: 0.5429
# Epoch 3/50
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0301 - accuracy: 0.6857
# Epoch 4/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9913 - accuracy: 0.6857
# Epoch 5/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9566 - accuracy: 0.6857
# Epoch 6/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9178 - accuracy: 0.6857
# Epoch 7/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8797 - accuracy: 0.6857
# Epoch 8/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8372 - accuracy: 0.6857
# Epoch 9/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7960 - accuracy: 0.6857
# Epoch 10/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7545 - accuracy: 0.6857
# Epoch 11/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7143 - accuracy: 0.6857
# Epoch 12/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6761 - accuracy: 0.6857
# Epoch 13/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6394 - accuracy: 0.6857
# Epoch 14/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6053 - accuracy: 0.6857
# Epoch 15/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5743 - accuracy: 0.6857
# Epoch 16/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5457 - accuracy: 0.6857
# Epoch 17/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5199 - accuracy: 0.6857
# Epoch 18/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4981 - accuracy: 0.6857
# Epoch 19/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4789 - accuracy: 0.7048
# Epoch 20/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4612 - accuracy: 0.7238
# Epoch 21/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4461 - accuracy: 0.7333
# Epoch 22/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4320 - accuracy: 0.7524
# Epoch 23/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4198 - accuracy: 0.7714
# Epoch 24/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4068 - accuracy: 0.8476
# Epoch 25/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3989 - accuracy: 0.8952
# Epoch 26/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3853 - accuracy: 0.8952
# Epoch 27/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3744 - accuracy: 0.8952
# Epoch 28/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3654 - accuracy: 0.8857
# Epoch 29/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3574 - accuracy: 0.8952
# Epoch 30/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3554 - accuracy: 0.9375
# Akurasi telah mencapai > 90%!
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3461 - accuracy: 0.9143
