# %%
# !wget --no-check-certificate \
  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
  -O /tmp/Chessman-image-dataset.zip
# Out:
# --2024-05-09 14:03:30--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2024-05-09 14:03:30--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   136MB/s    in 0.4s
#
# 2024-05-09 14:03:32 (136 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %%
import os
import zipfile
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
train_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 499 images belonging to 6 classes.
# Found 52 images belonging to 6 classes.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet152V2
model = tf.keras.models.Sequential([
    ResNet152V2(weights="imagenet", include_top=False, input_tensor=Input(shape=(150, 150, 3))),
    # tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
model.layers[0].trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 2s 0us/step

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=50,
                              verbose=2)
# Out:
# Epoch 1/50
# 63/63 - 153s - loss: 7.4762 - accuracy: 0.4429 - val_loss: 1.6656 - val_accuracy: 0.6923 - 153s/epoch - 2s/step
# Epoch 2/50
# 63/63 - 146s - loss: 1.4123 - accuracy: 0.7074 - val_loss: 1.9361 - val_accuracy: 0.6154 - 146s/epoch - 2s/step
# Epoch 3/50
# 63/63 - 150s - loss: 1.4996 - accuracy: 0.7395 - val_loss: 1.4336 - val_accuracy: 0.7692 - 150s/epoch - 2s/step
# Epoch 4/50
# 63/63 - 139s - loss: 1.2419 - accuracy: 0.7475 - val_loss: 1.7385 - val_accuracy: 0.6538 - 139s/epoch - 2s/step
# Epoch 5/50
# 63/63 - 145s - loss: 0.8298 - accuracy: 0.8257 - val_loss: 0.8132 - val_accuracy: 0.7885 - 145s/epoch - 2s/step
# Epoch 6/50
# 63/63 - 140s - loss: 0.6476 - accuracy: 0.8397 - val_loss: 0.9830 - val_accuracy: 0.7692 - 140s/epoch - 2s/step
# Epoch 7/50
# 63/63 - 149s - loss: 0.4876 - accuracy: 0.8878 - val_loss: 1.3942 - val_accuracy: 0.7115 - 149s/epoch - 2s/step
# Epoch 8/50
# 63/63 - 139s - loss: 0.7478 - accuracy: 0.8397 - val_loss: 1.5758 - val_accuracy: 0.7115 - 139s/epoch - 2s/step
# Epoch 9/50
# 63/63 - 150s - loss: 0.7897 - accuracy: 0.8517 - val_loss: 1.2608 - val_accuracy: 0.7115 - 150s/epoch - 2s/step
# Epoch 10/50
# 63/63 - 140s - loss: 0.3790 - accuracy: 0.9058 - val_loss: 1.3047 - val_accuracy: 0.6923 - 140s/epoch - 2s/step
# Epoch 11/50
# 63/63 - 141s - loss: 0.4001 - accuracy: 0.8938 - val_loss: 0.7678 - val_accuracy: 0.8462 - 141s/epoch - 2s/step
# Epoch 12/50
# 63/63 - 140s - loss: 0.3678 - accuracy: 0.9098 - val_loss: 1.4208 - val_accuracy: 0.7500 - 140s/epoch - 2s/step
# Epoch 13/50
# 63/63 - 150s - loss: 0.6547 - accuracy: 0.8918 - val_loss: 1.6833 - val_accuracy: 0.6731 - 150s/epoch - 2s/step
# Epoch 14/50
# 63/63 - 139s - loss: 0.5779 - accuracy: 0.8677 - val_loss: 1.8360 - val_accuracy: 0.6346 - 139s/epoch - 2s/step
# Epoch 15/50
# 63/63 - 150s - loss: 0.3338 - accuracy: 0.9198 - val_loss: 0.9794 - val_accuracy: 0.7500 - 150s/epoch - 2s/step
# Epoch 16/50
# 63/63 - 150s - loss: 0.3485 - accuracy: 0.9238 - val_loss: 1.5259 - val_accuracy: 0.7500 - 150s/epoch - 2s/step
# Epoch 17/50
# 63/63 - 150s - loss: 0.2708 - accuracy: 0.9299 - val_loss: 1.3239 - val_accuracy: 0.6923 - 150s/epoch - 2s/step
# Epoch 18/50
# 63/63 - 149s - loss: 0.3311 - accuracy: 0.9319 - val_loss: 1.3273 - val_accuracy: 0.8269 - 149s/epoch - 2s/step
# Epoch 19/50
# 63/63 - 140s - loss: 0.1626 - accuracy: 0.9499 - val_loss: 1.4806 - val_accuracy: 0.7115 - 140s/epoch - 2s/step
# Epoch 20/50
# 63/63 - 140s - loss: 0.2966 - accuracy: 0.9218 - val_loss: 1.2541 - val_accuracy: 0.7885 - 140s/epoch - 2s/step
# Epoch 21/50
# 63/63 - 139s - loss: 0.3180 - accuracy: 0.9299 - val_loss: 2.1506 - val_accuracy: 0.7500 - 139s/epoch - 2s/step
# Epoch 22/50
# 63/63 - 150s - loss: 0.4096 - accuracy: 0.9218 - val_loss: 1.2837 - val_accuracy: 0.7885 - 150s/epoch - 2s/step
# Epoch 23/50
# 63/63 - 139s - loss: 0.4198 - accuracy: 0.9178 - val_loss: 2.2348 - val_accuracy: 0.6731 - 139s/epoch - 2s/step
# Epoch 24/50
# 63/63 - 149s - loss: 0.3174 - accuracy: 0.9198 - val_loss: 0.9712 - val_accuracy: 0.7885 - 149s/epoch - 2s/step
# Epoch 25/50
# 63/63 - 148s - loss: 0.3630 - accuracy: 0.9178 - val_loss: 0.8713 - val_accuracy: 0.8462 - 148s/epoch - 2s/step
# Epoch 26/50
# 63/63 - 138s - loss: 0.3087 - accuracy: 0.9439 - val_loss: 1.6816 - val_accuracy: 0.8077 - 138s/epoch - 2s/step
# Epoch 27/50
# 63/63 - 148s - loss: 0.1743 - accuracy: 0.9619 - val_loss: 0.8888 - val_accuracy: 0.7115 - 148s/epoch - 2s/step
# Epoch 28/50
# 63/63 - 138s - loss: 0.1977 - accuracy: 0.9559 - val_loss: 0.6668 - val_accuracy: 0.7885 - 138s/epoch - 2s/step
# Epoch 29/50
# 63/63 - 148s - loss: 0.1454 - accuracy: 0.9519 - val_loss: 1.8188 - val_accuracy: 0.7115 - 148s/epoch - 2s/step
# Epoch 30/50
# 63/63 - 147s - loss: 0.1174 - accuracy: 0.9619 - val_loss: 1.7253 - val_accuracy: 0.7692 - 147s/epoch - 2s/step
# Epoch 31/50
# 63/63 - 138s - loss: 0.5148 - accuracy: 0.9158 - val_loss: 2.4090 - val_accuracy: 0.7692 - 138s/epoch - 2s/step
# Epoch 32/50
# 63/63 - 147s - loss: 0.5204 - accuracy: 0.9218 - val_loss: 1.3718 - val_accuracy: 0.7500 - 147s/epoch - 2s/step
# Epoch 33/50
# 63/63 - 149s - loss: 0.3558 - accuracy: 0.9279 - val_loss: 1.3743 - val_accuracy: 0.7115 - 149s/epoch - 2s/step
# Epoch 34/50
# 63/63 - 138s - loss: 0.2281 - accuracy: 0.9539 - val_loss: 1.4520 - val_accuracy: 0.8077 - 138s/epoch - 2s/step
# Epoch 35/50
# 63/63 - 148s - loss: 0.2315 - accuracy: 0.9579 - val_loss: 1.6866 - val_accuracy: 0.8269 - 148s/epoch - 2s/step
# Epoch 36/50
# 63/63 - 148s - loss: 0.1300 - accuracy: 0.9719 - val_loss: 0.6361 - val_accuracy: 0.8654 - 148s/epoch - 2s/step
# Epoch 37/50
# 63/63 - 139s - loss: 0.1026 - accuracy: 0.9780 - val_loss: 1.2053 - val_accuracy: 0.8077 - 139s/epoch - 2s/step
# Epoch 38/50
# 63/63 - 149s - loss: 0.1470 - accuracy: 0.9659 - val_loss: 1.2332 - val_accuracy: 0.7692 - 149s/epoch - 2s/step
# Epoch 39/50
# 63/63 - 149s - loss: 0.1007 - accuracy: 0.9780 - val_loss: 0.8365 - val_accuracy: 0.8269 - 149s/epoch - 2s/step
# Epoch 40/50
# 63/63 - 138s - loss: 0.0938 - accuracy: 0.9739 - val_loss: 0.9591 - val_accuracy: 0.7885 - 138s/epoch - 2s/step
# Epoch 41/50
# 63/63 - 148s - loss: 0.1804 - accuracy: 0.9679 - val_loss: 1.2058 - val_accuracy: 0.7115 - 148s/epoch - 2s/step
# Epoch 42/50
# 63/63 - 147s - loss: 0.2423 - accuracy: 0.9559 - val_loss: 2.6407 - val_accuracy: 0.6731 - 147s/epoch - 2s/step
# Epoch 43/50
# 63/63 - 148s - loss: 0.3228 - accuracy: 0.9399 - val_loss: 0.9230 - val_accuracy: 0.7692 - 148s/epoch - 2s/step
# Epoch 44/50
# 63/63 - 139s - loss: 0.1728 - accuracy: 0.9639 - val_loss: 1.2717 - val_accuracy: 0.7115 - 139s/epoch - 2s/step
# Epoch 45/50
# 63/63 - 138s - loss: 0.2058 - accuracy: 0.9479 - val_loss: 1.1423 - val_accuracy: 0.7692 - 138s/epoch - 2s/step
# Epoch 46/50
# 63/63 - 137s - loss: 0.0807 - accuracy: 0.9739 - val_loss: 0.7508 - val_accuracy: 0.8462 - 137s/epoch - 2s/step
# Epoch 47/50
# 63/63 - 148s - loss: 0.1469 - accuracy: 0.9719 - val_loss: 0.8876 - val_accuracy: 0.8462 - 148s/epoch - 2s/step
# Epoch 48/50
# 63/63 - 138s - loss: 0.0550 - accuracy: 0.9800 - val_loss: 1.1638 - val_accuracy: 0.7115 - 138s/epoch - 2s/step
# Epoch 49/50
# 63/63 - 149s - loss: 0.1168 - accuracy: 0.9719 - val_loss: 1.3167 - val_accuracy: 0.7115 - 149s/epoch - 2s/step
# Epoch 50/50
# 63/63 - 139s - loss: 0.0672 - accuracy: 0.9780 - val_loss: 0.5866 - val_accuracy: 0.7885 - 139s/epoch - 2s/step
