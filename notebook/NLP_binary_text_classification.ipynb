# %%
import pandas as pd
df = pd.read_csv('yelp_labelled.txt', names=['sentence', 'label'], sep='\t')

# %%
df.tail()
# Out:
#                                               sentence  label
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
from sklearn.model_selection import train_test_split

kalimat = df['sentence'].values
y = df['label'].values
kalimat_latih, kalimat_test, y_latih, y_test = train_test_split(kalimat, y, test_size=0.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=250, oov_token='x')
tokenizer.fit_on_texts(kalimat_latih)
tokenizer.fit_on_texts(kalimat_test)

sekuens_latih = tokenizer.texts_to_sequences(kalimat_latih)
sekuens_test = tokenizer.texts_to_sequences(kalimat_test)

padded_latih = pad_sequences(sekuens_latih, maxlen=20)
padded_test = pad_sequences(sekuens_test, maxlen=20)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(250, 16, input_length=20),
    tf.keras.layers.GlobalAveragePooling1D(), # Sama seperti flatten, hanya saja lebih bagus
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
num_epochs = 30
history = model.fit(
    padded_latih,
    y_latih,
    epochs=num_epochs,
    validation_data=(padded_test, y_test),
    verbose=2
)
# Out:
# Epoch 1/30
# 25/25 - 1s - loss: 0.6923 - accuracy: 0.5350 - val_loss: 0.6912 - val_accuracy: 0.5800 - 1s/epoch - 49ms/step
# Epoch 2/30
# 25/25 - 0s - loss: 0.6894 - accuracy: 0.5713 - val_loss: 0.6879 - val_accuracy: 0.6200 - 80ms/epoch - 3ms/step
# Epoch 3/30
# 25/25 - 0s - loss: 0.6839 - accuracy: 0.6162 - val_loss: 0.6828 - val_accuracy: 0.6600 - 91ms/epoch - 4ms/step
# Epoch 4/30
# 25/25 - 0s - loss: 0.6763 - accuracy: 0.6375 - val_loss: 0.6752 - val_accuracy: 0.6550 - 92ms/epoch - 4ms/step
# Epoch 5/30
# 25/25 - 0s - loss: 0.6647 - accuracy: 0.6612 - val_loss: 0.6632 - val_accuracy: 0.6750 - 106ms/epoch - 4ms/step
# Epoch 6/30
# 25/25 - 0s - loss: 0.6471 - accuracy: 0.7275 - val_loss: 0.6479 - val_accuracy: 0.6750 - 95ms/epoch - 4ms/step
# Epoch 7/30
# 25/25 - 0s - loss: 0.6236 - accuracy: 0.7375 - val_loss: 0.6260 - val_accuracy: 0.7300 - 89ms/epoch - 4ms/step
# Epoch 8/30
# 25/25 - 0s - loss: 0.5923 - accuracy: 0.7725 - val_loss: 0.6030 - val_accuracy: 0.7450 - 79ms/epoch - 3ms/step
# Epoch 9/30
# 25/25 - 0s - loss: 0.5581 - accuracy: 0.7962 - val_loss: 0.5779 - val_accuracy: 0.7700 - 79ms/epoch - 3ms/step
# Epoch 10/30
# 25/25 - 0s - loss: 0.5220 - accuracy: 0.8112 - val_loss: 0.5545 - val_accuracy: 0.7650 - 80ms/epoch - 3ms/step
# Epoch 11/30
# 25/25 - 0s - loss: 0.4867 - accuracy: 0.8313 - val_loss: 0.5337 - val_accuracy: 0.7450 - 98ms/epoch - 4ms/step
# Epoch 12/30
# 25/25 - 0s - loss: 0.4535 - accuracy: 0.8350 - val_loss: 0.5144 - val_accuracy: 0.7600 - 86ms/epoch - 3ms/step
# Epoch 13/30
# 25/25 - 0s - loss: 0.4251 - accuracy: 0.8400 - val_loss: 0.4986 - val_accuracy: 0.7550 - 88ms/epoch - 4ms/step
# Epoch 14/30
# 25/25 - 0s - loss: 0.4017 - accuracy: 0.8525 - val_loss: 0.4878 - val_accuracy: 0.7800 - 92ms/epoch - 4ms/step
# Epoch 15/30
# 25/25 - 0s - loss: 0.3814 - accuracy: 0.8600 - val_loss: 0.4788 - val_accuracy: 0.7750 - 93ms/epoch - 4ms/step
# Epoch 16/30
# 25/25 - 0s - loss: 0.3646 - accuracy: 0.8575 - val_loss: 0.4690 - val_accuracy: 0.7700 - 101ms/epoch - 4ms/step
# Epoch 17/30
# 25/25 - 0s - loss: 0.3497 - accuracy: 0.8587 - val_loss: 0.4640 - val_accuracy: 0.7800 - 84ms/epoch - 3ms/step
# Epoch 18/30
# 25/25 - 0s - loss: 0.3355 - accuracy: 0.8637 - val_loss: 0.4641 - val_accuracy: 0.7850 - 99ms/epoch - 4ms/step
# Epoch 19/30
# 25/25 - 0s - loss: 0.3257 - accuracy: 0.8775 - val_loss: 0.4588 - val_accuracy: 0.7650 - 85ms/epoch - 3ms/step
# Epoch 20/30
# 25/25 - 0s - loss: 0.3184 - accuracy: 0.8725 - val_loss: 0.4547 - val_accuracy: 0.7800 - 98ms/epoch - 4ms/step
# Epoch 21/30
# 25/25 - 0s - loss: 0.3057 - accuracy: 0.8763 - val_loss: 0.4536 - val_accuracy: 0.7800 - 97ms/epoch - 4ms/step
# Epoch 22/30
# 25/25 - 0s - loss: 0.2974 - accuracy: 0.8775 - val_loss: 0.4548 - val_accuracy: 0.7750 - 82ms/epoch - 3ms/step
# Epoch 23/30
# 25/25 - 0s - loss: 0.2928 - accuracy: 0.8988 - val_loss: 0.4645 - val_accuracy: 0.7950 - 82ms/epoch - 3ms/step
# Epoch 24/30
# 25/25 - 0s - loss: 0.2908 - accuracy: 0.8800 - val_loss: 0.4517 - val_accuracy: 0.7900 - 92ms/epoch - 4ms/step
# Epoch 25/30
# 25/25 - 0s - loss: 0.2840 - accuracy: 0.8863 - val_loss: 0.4531 - val_accuracy: 0.7750 - 87ms/epoch - 3ms/step
# Epoch 26/30
# 25/25 - 0s - loss: 0.2745 - accuracy: 0.8863 - val_loss: 0.4543 - val_accuracy: 0.7700 - 91ms/epoch - 4ms/step
# Epoch 27/30
# 25/25 - 0s - loss: 0.2700 - accuracy: 0.8938 - val_loss: 0.4587 - val_accuracy: 0.7850 - 107ms/epoch - 4ms/step
# Epoch 28/30
# 25/25 - 0s - loss: 0.2654 - accuracy: 0.8938 - val_loss: 0.4622 - val_accuracy: 0.7800 - 93ms/epoch - 4ms/step
# Epoch 29/30
# 25/25 - 0s - loss: 0.2610 - accuracy: 0.8975 - val_loss: 0.4587 - val_accuracy: 0.7700 - 80ms/epoch - 3ms/step
# Epoch 30/30
# 25/25 - 0s - loss: 0.2577 - accuracy: 0.8938 - val_loss: 0.4652 - val_accuracy: 0.7750 - 79ms/epoch - 3ms/step
